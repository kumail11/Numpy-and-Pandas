# %%
import pandas as pd

# %%
myData = pd.read_csv("secondary_institutions.csv")

newData = pd.DataFrame(myData)

newData
# Out:
#                X             Y  objectid  inst_id  \
# 0    623662.3240  2.354705e+06         1   111911
# 1    623662.6003  2.354705e+06         2   111911
# 2    623662.3240  2.354705e+06         3   111911
# 3    609818.8490  2.361944e+06         4   111911
# 4    597791.4945  2.376579e+06         5   111911
# 5    615049.3119  2.362377e+06         6   111911
# 6    613225.0778  2.365291e+06         7   111911
# 7    910925.5839  2.183100e+06         8   111920
# 8    910925.5839  2.183100e+06         9   111920
# 9    910925.5839  2.183100e+06        10   111920
# 10   910925.5839  2.183100e+06        11   111920
# 11   910925.5839  2.183100e+06        12   111920
# 12   910925.5839  2.183100e+06        13   111920
# 13   910925.5839  2.183100e+06        14   111920
# 14   910925.5839  2.183100e+06        15   111920
# 15   622505.7127  2.355806e+06        16   111939
# 16   622505.7127  2.355806e+06        17   111939
# 17   622505.7127  2.355806e+06        18   111939
# ...

# %%
std_data = pd.read_excel("student.xlsx")
st_data = pd.DataFrame(std_data)

st_data
# Out:
#    ID     Name  Roll No  Semester  CGPA
# 0   1      Ali        8         5   3.2
# 1   2   Hassan        3         5   3.4
# 2   3  Hussain        4         2   3.5
# 3   4    Mehdi        7         6   3.1

# %%
desc = st_data.describe()
desc
# Out:
#         Roll No  Semester      CGPA
# count  4.000000  4.000000  4.000000
# mean   5.500000  4.500000  3.300000
# std    2.380476  1.732051  0.182574
# min    3.000000  2.000000  3.100000
# 25%    3.750000  4.250000  3.175000
# 50%    5.500000  5.000000  3.300000
# 75%    7.250000  5.250000  3.425000
# max    8.000000  6.000000  3.500000

# %%
st_data.iloc[0:]
# Out:
#       Name  Roll No  Semester  CGPA
# 0      Ali        8         5   3.2
# 1   Hassan        3         5   3.4
# 2  Hussain        4         2   3.5
# 3    Mehdi        7         6   3.1

# %%
st_data.loc[0:, ["Name", "Semester"]]
# Out:
#       Name  Semester
# 0      Ali         5
# 1   Hassan         5
# 2  Hussain         2
# 3    Mehdi         6

# %%
st_data
# Out:
#    ID     Name  Roll No  Semester  CGPA
# 0   1      Ali        8         5   3.2
# 1   2   Hassan        3         5   3.4
# 2   3  Hussain        4         2   3.5
# 3   4    Mehdi        7         6   3.1

# %%
st_data.loc[st_data['ID'] > 1, "CGPA"] = 3.6

st_data
# Out:
#    ID     Name  Roll No  Semester  CGPA
# 0   1      Ali        8         5   3.2
# 1   2   Hassan        3         5   3.6
# 2   3  Hussain        4         2   3.6
# 3   4    Mehdi        7         6   3.6

# %%
ID = [1, 2]
education = ["Bachelors", "Masters"]
salary = [50000, 90000]

myFrame = pd.DataFrame({"ID": ID, "Education": education, "Salary": salary})

myFrame
# Out:
#    ID  Education  Salary
# 0   1  Bachelors   50000
# 1   2    Masters   90000

# %%
# import data from DataFrame to excel file (xlsx)..!!
myFrame.to_excel("edu_salary.xlsx", index = False)

# %%
# ix indexing works just the same as .loc when passed strings
data.ix[['Andrade']] == data.loc[['Andrade']]

# ix indexing works the same as .iloc when passed integers.
data.ix[[33]] == data.iloc[[33]]
 
# ix only works in both modes when the index of the DataFrame is NOT an integer itself.

# %%
tempDic = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
          {'a': 100, 'b': 200, 'c': 300, 'd': 400},
          {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]

useDict = pd.DataFrame(tempDic)

useDict
# Out:
#       a     b     c     d
# 0     1     2     3     4
# 1   100   200   300   400
# 2  1000  2000  3000  4000

# %%
useDict.iloc[1]
# Out:
# a    100
# b    200
# c    300
# d    400
# Name: 1, dtype: int64

# %%
useDict.iloc[lambda temp: temp.index % 2 == 0]
# Out:
#       a     b     c     d
# 0     1     2     3     4
# 2  1000  2000  3000  4000

# %%
useDict.dtypes
# Out:
# a    int64
# b    int64
# c    int64
# d    int64
# dtype: object

# %%
useDict.values
# Out:
# array([[   1,    2,    3,    4],
#        [ 100,  200,  300,  400],
#        [1000, 2000, 3000, 4000]], dtype=int64)

# %%
useDict.axes
# Out:
# [RangeIndex(start=0, stop=3, step=1),
#  Index(['a', 'b', 'c', 'd'], dtype='object')]

# %%
useDict.size
# Out:
# 12

# %%
useDict.shape
# Out:
# (3, 4)

# %%
dic_empty = pd.DataFrame({"A" : []})

dic_empty
# Out:
# Empty DataFrame
# Columns: [A]
# Index: []

# %%
dic_empty.empty
# Out:
# True

# %%
st_data
# Out:
#    ID     Name  Roll No  Semester  CGPA
# 0   1      Ali        8         5   3.2
# 1   2   Hassan        3         5   3.6
# 2   3  Hussain        4         2   3.6
# 3   4    Mehdi        7         6   3.6

# %%
greaterCGPA = st_data["CGPA"] > 3.5

st_data[greaterCGPA]
# Out:
#    ID     Name  Roll No  Semester  CGPA
# 1   2   Hassan        3         5   3.6
# 2   3  Hussain        4         2   3.6
# 3   4    Mehdi        7         6   3.6

# %%
covdata = pd.read_csv("covid_19_data.csv")

covid_data = pd.DataFrame(covdata)

covid_data
# Out:
#            Date  Cases  Deaths  Recovered          Travel_history  \
# 0     2/26/2020      1       0          0                   China
# 1     2/26/2020      2       0          0             Iran/Taftan
# 2     2/29/2020      1       0          0                   China
# 3     2/29/2020      1       0          0             Iran/Taftan
# 4      3/2/2020      1       0          0             Iran/Taftan
# 5      3/6/2020      0       0          1                 Unknown
# 6      3/7/2020      1       0          0             Iran/Taftan
# 7      3/9/2020      6       0          0                   Syria
# 8      3/9/2020      3       0          0                      UK
# 9     3/10/2020      1       0          0             Iran/Taftan
# 10    3/10/2020      1       0          0                   Syria
# 11    3/10/2020      1       0          0             Iran/Taftan
# 12    3/11/2020      1       0          0             Iran/Taftan
# ...

# %%
sort_by_cases = covid_data["Cases"] > 10

covid_data[sort_by_cases]
# Out:
#            Date  Cases  Deaths  Recovered          Travel_history  \
# 18    3/15/2020     13       0          0             Iran/Taftan
# 21    3/15/2020     15       0          0             Iran/Taftan
# 23    3/16/2020    119       0          0             Iran/Taftan
# 24    3/16/2020     26       0          0             Iran/Taftan
# 30    3/17/2020     15       0          0             Iran/Taftan
# 31    3/17/2020     24       0          0             Iran/Taftan
# 40    3/18/2020     31       0          0             Iran/Taftan
# 49    3/19/2020     44       0          0             Iran/Taftan
# 50    3/19/2020     37       0          1  Local - Social Contact
# 51    3/19/2020     53       0          0             Iran/Taftan
# 67    3/20/2020     16       0          0  Local - Social Contact
# 69    3/21/2020     12       0          0             Iran/Taftan
# 70    3/21/2020     39       0          0             Iran/Taftan
# ...
