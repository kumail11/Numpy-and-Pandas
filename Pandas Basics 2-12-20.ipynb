# %%
import pandas as pd

# %%
readCSV = pd.read_csv('direct_marketing.csv')

# %%
myFrame = pd.DataFrame(readCSV)

myFrame
# Out:
#        recency   history_segment  history  mens  womens   zip_code  newbie  \
# 0           10    2) $100 - $200   142.44     1       0  Surburban       0
# 1            6    3) $200 - $350   329.08     1       1      Rural       1
# 2            7    2) $100 - $200   180.65     0       1  Surburban       1
# 3            9    5) $500 - $750   675.83     1       0      Rural       1
# 4            2      1) $0 - $100    45.34     1       0      Urban       0
# 5            6    2) $100 - $200   134.83     0       1  Surburban       0
# 6            9    3) $200 - $350   280.20     1       0  Surburban       1
# 7            9      1) $0 - $100    46.42     0       1      Urban       0
# 8            9    5) $500 - $750   675.07     1       1      Rural       1
# 9           10      1) $0 - $100    32.84     0       1      Urban       1
# 10           7    5) $500 - $750   548.91     0       1      Urban       1
# ...

# %%
myFrame.head(15)
# Out:
#     recency history_segment  history  mens  womens   zip_code  newbie  \
# 0        10  2) $100 - $200   142.44     1       0  Surburban       0
# 1         6  3) $200 - $350   329.08     1       1      Rural       1
# 2         7  2) $100 - $200   180.65     0       1  Surburban       1
# 3         9  5) $500 - $750   675.83     1       0      Rural       1
# 4         2    1) $0 - $100    45.34     1       0      Urban       0
# 5         6  2) $100 - $200   134.83     0       1  Surburban       0
# 6         9  3) $200 - $350   280.20     1       0  Surburban       1
# 7         9    1) $0 - $100    46.42     0       1      Urban       0
# 8         9  5) $500 - $750   675.07     1       1      Rural       1
# 9        10    1) $0 - $100    32.84     0       1      Urban       1
# 10        7  5) $500 - $750   548.91     0       1      Urban       1
# 11        1  3) $200 - $350   211.45     0       1      Urban       1
# ...

# %%
myFrame.tail(15)
# Out:
#        recency history_segment  history  mens  womens   zip_code  newbie  \
# 63985        9    1) $0 - $100    29.99     1       0      Urban       0
# 63986        9    1) $0 - $100    35.26     0       1      Urban       1
# 63987        1    1) $0 - $100    79.70     1       0  Surburban       1
# 63988        6    1) $0 - $100    32.98     1       0  Surburban       0
# 63989       10  3) $200 - $350   304.30     1       1  Surburban       0
# 63990        6    1) $0 - $100    80.02     0       1  Surburban       0
# 63991        1  3) $200 - $350   306.10     1       0  Surburban       1
# 63992        1  5) $500 - $750   519.69     1       1      Urban       1
# 63993        4  4) $350 - $500   374.07     0       1  Surburban       0
# 63994        7    1) $0 - $100    86.46     0       1      Urban       0
# 63995       10  2) $100 - $200   105.54     1       0      Urban       0
# 63996        5    1) $0 - $100    38.91     0       1      Urban       1
# ...

# %%
myFrame.describe()
# Out:
#             recency       history          mens        womens        newbie  \
# count  64000.000000  64000.000000  64000.000000  64000.000000  64000.000000
# mean       5.763734    242.085656      0.551031      0.549719      0.502250
# std        3.507592    256.158608      0.497393      0.497526      0.499999
# min        1.000000     29.990000      0.000000      0.000000      0.000000
# 25%        2.000000     64.660000      0.000000      0.000000      0.000000
# 50%        6.000000    158.110000      1.000000      1.000000      1.000000
# 75%        9.000000    325.657500      1.000000      1.000000      1.000000
# max       12.000000   3345.930000      1.000000      1.000000      1.000000
#
#               visit    conversion         spend   DM_category
# count  64000.000000  64000.000000  64000.000000  64000.000000
# mean       0.146781      0.009031      1.050908      3.851750
# std        0.353890      0.094604     15.036448      2.131944
# ...

# %%
myFrame.shape
# Out:
# (64000, 13)

# %%
myFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64000 entries, 0 to 63999
# Data columns (total 13 columns):
# recency            64000 non-null int64
# history_segment    64000 non-null object
# history            64000 non-null float64
# mens               64000 non-null int64
# womens             64000 non-null int64
# zip_code           64000 non-null object
# newbie             64000 non-null int64
# channel            64000 non-null object
# segment            64000 non-null object
# visit              64000 non-null int64
# conversion         64000 non-null int64
# spend              64000 non-null float64
# DM_category        64000 non-null int64
# dtypes: float64(2), int64(7), object(4)
# memory usage: 6.3+ MB

# %%
myFrame.describe()
# Out:
#             recency       history          mens        womens        newbie  \
# count  64000.000000  64000.000000  64000.000000  64000.000000  64000.000000
# mean       5.763734    242.085656      0.551031      0.549719      0.502250
# std        3.507592    256.158608      0.497393      0.497526      0.499999
# min        1.000000     29.990000      0.000000      0.000000      0.000000
# 25%        2.000000     64.660000      0.000000      0.000000      0.000000
# 50%        6.000000    158.110000      1.000000      1.000000      1.000000
# 75%        9.000000    325.657500      1.000000      1.000000      1.000000
# max       12.000000   3345.930000      1.000000      1.000000      1.000000
#
#               visit    conversion         spend   DM_category
# count  64000.000000  64000.000000  64000.000000  64000.000000
# mean       0.146781      0.009031      1.050908      3.851750
# std        0.353890      0.094604     15.036448      2.131944
# ...

# %%
myFrame.columns
# Out:
# Index(['recency', 'history_segment', 'history', 'mens', 'womens', 'zip_code',
#        'newbie', 'channel', 'segment', 'visit', 'conversion', 'spend',
#        'DM_category'],
#       dtype='object')

# %%
myFrame.loc[0:50000]
# Out:
#        recency   history_segment  history  mens  womens   zip_code  newbie  \
# 0           10    2) $100 - $200   142.44     1       0  Surburban       0
# 1            6    3) $200 - $350   329.08     1       1      Rural       1
# 2            7    2) $100 - $200   180.65     0       1  Surburban       1
# 3            9    5) $500 - $750   675.83     1       0      Rural       1
# 4            2      1) $0 - $100    45.34     1       0      Urban       0
# 5            6    2) $100 - $200   134.83     0       1  Surburban       0
# 6            9    3) $200 - $350   280.20     1       0  Surburban       1
# 7            9      1) $0 - $100    46.42     0       1      Urban       0
# 8            9    5) $500 - $750   675.07     1       1      Rural       1
# 9           10      1) $0 - $100    32.84     0       1      Urban       1
# 10           7    5) $500 - $750   548.91     0       1      Urban       1
# ...

# %%
abc = myFrame.loc[0:3, ['recency', 'history', 'mens']]

abc
# Out:
#    recency  history  mens
# 0       10   142.44     1
# 1        6   329.08     1
# 2        7   180.65     0
# 3        9   675.83     1

# %%
myFrame.dtypes
# Out:
# recency              int64
# history_segment     object
# history            float64
# mens                 int64
# womens               int64
# zip_code            object
# newbie               int64
# channel             object
# segment             object
# visit                int64
# conversion           int64
# spend              float64
# DM_category          int64
# dtype: object

# %%
myFrame.mens
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
# 5        0
# 6        1
# 7        0
# 8        1
# 9        0
# 10       0
# 11       0
# 12       0
# 13       0
# 14       0
# 15       1
# 16       1
# 17       1
# 18       1
# 19       1
# 20       0
# 21       1
# 22       1
# 23       0
# 24       1
# 25       0
# 26       0
# 27       0
# 28       0
# 29       1
#         ..
# 63970    0
# 63971    0
# 63972    0
# 63973    1
# 63974    0
# 63975    1
# 63976    1
# 63977    0
# 63978    0
# 63979    0
# 63980    0
# 63981    0
# 63982    1
# 63983    0
# 63984    0
# 63985    1
# 63986    0
# 63987    1
# 63988    1
# 63989    1
# 63990    0
# 63991    1
# 63992    1
# 63993    0
# 63994    0
# 63995    1
# 63996    0
# 63997    1
# 63998    1
# 63999    0
# Name: mens, Length: 64000, dtype: int64

# %%
myFrame['mens']
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
# 5        0
# 6        1
# 7        0
# 8        1
# 9        0
# 10       0
# 11       0
# 12       0
# 13       0
# 14       0
# 15       1
# 16       1
# 17       1
# 18       1
# 19       1
# 20       0
# 21       1
# 22       1
# 23       0
# 24       1
# 25       0
# 26       0
# 27       0
# 28       0
# 29       1
#         ..
# 63970    0
# 63971    0
# 63972    0
# 63973    1
# 63974    0
# 63975    1
# 63976    1
# 63977    0
# 63978    0
# 63979    0
# 63980    0
# 63981    0
# 63982    1
# 63983    0
# 63984    0
# 63985    1
# 63986    0
# 63987    1
# 63988    1
# 63989    1
# 63990    0
# 63991    1
# 63992    1
# 63993    0
# 63994    0
# 63995    1
# 63996    0
# 63997    1
# 63998    1
# 63999    0
# Name: mens, Length: 64000, dtype: int64

# %%
myFrame.loc[:, 'mens']
# Out:
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
# 5        0
# 6        1
# 7        0
# 8        1
# 9        0
# 10       0
# 11       0
# 12       0
# 13       0
# 14       0
# 15       1
# 16       1
# 17       1
# 18       1
# 19       1
# 20       0
# 21       1
# 22       1
# 23       0
# 24       1
# 25       0
# 26       0
# 27       0
# 28       0
# 29       1
#         ..
# 63970    0
# 63971    0
# 63972    0
# 63973    1
# 63974    0
# 63975    1
# 63976    1
# 63977    0
# 63978    0
# 63979    0
# 63980    0
# 63981    0
# 63982    1
# 63983    0
# 63984    0
# 63985    1
# 63986    0
# 63987    1
# 63988    1
# 63989    1
# 63990    0
# 63991    1
# 63992    1
# 63993    0
# 63994    0
# 63995    1
# 63996    0
# 63997    1
# 63998    1
# 63999    0
# Name: mens, Length: 64000, dtype: int64

# %%
# myFrame1.loc[0:50000, ['recency', 'zip_code', 'DM_category']]

r = myFrame.recency
z = myFrame.zip_code
d = myFrame.DM_category

myFrame1 = pd.concat([r, z, d], axis = 1)

myFrame1
# Out:
#        recency   zip_code  DM_category
# 0           10  Surburban            4
# 1            6      Rural           11
# 2            7  Surburban            1
# 3            9      Rural            2
# 4            2      Urban            4
# 5            6  Surburban            1
# 6            9  Surburban            4
# 7            9      Urban            1
# 8            9      Rural            5
# 9           10      Urban            1
# 10           7      Urban            1
# 11           1      Urban            1
# 12           5  Surburban            1
# 13           2      Urban            3
# 14           4      Rural            5
# 15           3      Urban            6
# 16           5  Surburban            2
# 17           9      Rural            2
# 18          11  Surburban            5
# 19           5  Surburban            2
# 20           9  Surburban            5
# 21          11  Surburban            2
# 22           2  Surburban            2
# ...

# %%
myFrame.recency < 7
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
# 5         True
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17       False
# 18       False
# 19        True
# 20       False
# 21       False
# 22        True
# 23        True
# 24        True
# 25        True
# 26       False
# 27        True
# 28       False
# 29        True
#          ...
# 63970     True
# 63971     True
# 63972     True
# 63973    False
# 63974    False
# 63975    False
# 63976     True
# 63977    False
# 63978    False
# 63979    False
# 63980     True
# 63981     True
# 63982     True
# 63983     True
# 63984     True
# 63985    False
# 63986    False
# 63987     True
# 63988     True
# 63989    False
# 63990     True
# 63991     True
# 63992     True
# 63993     True
# 63994    False
# 63995    False
# 63996     True
# ...

# %%
myFrame[myFrame.recency < 7]
# Out:
#        recency   history_segment  history  mens  womens   zip_code  newbie  \
# 1            6    3) $200 - $350   329.08     1       1      Rural       1
# 4            2      1) $0 - $100    45.34     1       0      Urban       0
# 5            6    2) $100 - $200   134.83     0       1  Surburban       0
# 11           1    3) $200 - $350   211.45     0       1      Urban       1
# 12           5    5) $500 - $750   642.90     0       1  Surburban       1
# 13           2    2) $100 - $200   101.64     0       1      Urban       0
# 14           4    3) $200 - $350   241.42     0       1      Rural       1
# 15           3      1) $0 - $100    58.13     1       0      Urban       1
# 16           5      1) $0 - $100    29.99     1       0  Surburban       0
# 19           5  6) $750 - $1,000   828.42     1       0  Surburban       1
# 22           2    2) $100 - $200   118.40     1       0  Surburban       0
# ...

# %%
myFrame[myFrame.zip_code == 'Urban']
# Out:
#        recency   history_segment  history  mens  womens zip_code  newbie  \
# 4            2      1) $0 - $100    45.34     1       0    Urban       0
# 7            9      1) $0 - $100    46.42     0       1    Urban       0
# 9           10      1) $0 - $100    32.84     0       1    Urban       1
# 10           7    5) $500 - $750   548.91     0       1    Urban       1
# 11           1    3) $200 - $350   211.45     0       1    Urban       1
# 13           2    2) $100 - $200   101.64     0       1    Urban       0
# 15           3      1) $0 - $100    58.13     1       0    Urban       1
# 23           2      1) $0 - $100    29.99     0       1    Urban       1
# 28           7    4) $350 - $500   435.73     0       1    Urban       1
# 31           9    3) $200 - $350   334.24     1       0    Urban       0
# 32           6    2) $100 - $200   128.01     0       1    Urban       0
# 35           4    3) $200 - $350   218.72     0       1    Urban       0
# ...

# %%
myFrame[myFrame.DM_category == 5]
# Out:
#        recency   history_segment  history  mens  womens   zip_code  newbie  \
# 8            9    5) $500 - $750   675.07     1       1      Rural       1
# 14           4    3) $200 - $350   241.42     0       1      Rural       1
# 18          11    3) $200 - $350   219.04     1       1  Surburban       0
# 20           9      1) $0 - $100    29.99     0       1  Surburban       1
# 23           2      1) $0 - $100    29.99     0       1      Urban       1
# 28           7    4) $350 - $500   435.73     0       1      Urban       1
# 37           4  6) $750 - $1,000   766.47     1       1      Urban       1
# 40          11    3) $200 - $350   236.97     1       1      Urban       1
# 44           1      1) $0 - $100    48.32     0       1      Urban       0
# 47           1    5) $500 - $750   729.70     1       1  Surburban       1
# 50           3    3) $200 - $350   203.30     0       1  Surburban       0
# ...

# %%
myFrame[myFrame.channel == 'Web']
# Out:
#        recency   history_segment  history  mens  womens   zip_code  newbie  \
# 1            6    3) $200 - $350   329.08     1       1      Rural       1
# 2            7    2) $100 - $200   180.65     0       1  Surburban       1
# 3            9    5) $500 - $750   675.83     1       0      Rural       1
# 4            2      1) $0 - $100    45.34     1       0      Urban       0
# 9           10      1) $0 - $100    32.84     0       1      Urban       1
# 13           2    2) $100 - $200   101.64     0       1      Urban       0
# 15           3      1) $0 - $100    58.13     1       0      Urban       1
# 17           9    2) $100 - $200   112.35     1       0      Rural       0
# 22           2    2) $100 - $200   118.40     1       0  Surburban       0
# 24           4      1) $0 - $100    78.24     1       0  Surburban       0
# 25           6    2) $100 - $200   139.87     0       1      Rural       1
# ...

# %%
myFrame[myFrame.channel != 'Web']
# Out:
#        recency   history_segment  history  mens  womens   zip_code  newbie  \
# 0           10    2) $100 - $200   142.44     1       0  Surburban       0
# 5            6    2) $100 - $200   134.83     0       1  Surburban       0
# 6            9    3) $200 - $350   280.20     1       0  Surburban       1
# 7            9      1) $0 - $100    46.42     0       1      Urban       0
# 8            9    5) $500 - $750   675.07     1       1      Rural       1
# 10           7    5) $500 - $750   548.91     0       1      Urban       1
# 11           1    3) $200 - $350   211.45     0       1      Urban       1
# 12           5    5) $500 - $750   642.90     0       1  Surburban       1
# 14           4    3) $200 - $350   241.42     0       1      Rural       1
# 16           5      1) $0 - $100    29.99     1       0  Surburban       0
# 18          11    3) $200 - $350   219.04     1       1  Surburban       0
# ...

# %%
myFrame[ (myFrame.recency < 7) & (myFrame.newbie == 0)]
# Out:
#        recency history_segment  history  mens  womens   zip_code  newbie  \
# 4            2    1) $0 - $100    45.34     1       0      Urban       0
# 5            6  2) $100 - $200   134.83     0       1  Surburban       0
# 13           2  2) $100 - $200   101.64     0       1      Urban       0
# 16           5    1) $0 - $100    29.99     1       0  Surburban       0
# 22           2  2) $100 - $200   118.40     1       0  Surburban       0
# 24           4    1) $0 - $100    78.24     1       0  Surburban       0
# 27           6  2) $100 - $200   162.98     0       1  Surburban       0
# 29           2  3) $200 - $350   203.35     1       0      Rural       0
# 30           2  3) $200 - $350   237.53     0       1  Surburban       0
# 32           6  2) $100 - $200   128.01     0       1      Urban       0
# 34           3    1) $0 - $100    29.99     1       0      Rural       0
# 35           4  3) $200 - $350   218.72     0       1      Urban       0
# ...

# %%
myFrame[ (myFrame.zip_code == 'Urban') & (myFrame.channel == 'Phone') & (myFrame.DM_category == 4) ]
# Out:
#        recency   history_segment  history  mens  womens zip_code  newbie  \
# 48           3    2) $100 - $200   134.59     1       0    Urban       1
# 71          10      1) $0 - $100    31.12     1       0    Urban       0
# 108          2      1) $0 - $100    66.60     1       0    Urban       1
# 134          9    2) $100 - $200   123.39     1       0    Urban       0
# 201         10    2) $100 - $200   170.32     1       0    Urban       1
# 234         10    2) $100 - $200   132.46     1       0    Urban       0
# 313         12      1) $0 - $100    75.26     1       0    Urban       1
# 357          4      1) $0 - $100    29.99     1       0    Urban       0
# 359          2  6) $750 - $1,000   936.63     1       0    Urban       1
# 387          8      1) $0 - $100    60.69     1       0    Urban       1
# 408          9    2) $100 - $200   157.76     1       0    Urban       0
# 431          7      1) $0 - $100    63.95     1       0    Urban       1
# ...

# %%
myFrame[myFrame.channel == 'Multichannel'] = 'null'

myFrame
# Out:
#   File "<ipython-input-45-b1701e47a212>", line 1
#     myFrame[myFrame.channel == channel.'Multichannel'] = 'null'
#                                                     ^
# SyntaxError: invalid syntax
